# %% [markdown]
# ## Matplotlib lab 1

# %% [markdown]
# ### Importing matplotlib function

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### ploting a simple plot

# %%
x=[1,2,3,4,5]
y=[5,9,2,1,4]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Ploting without line

# %%
plt.plot(x,y,'o')
plt.show()
